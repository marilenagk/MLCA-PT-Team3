# %%
# import json file argument data set

import json
import pandas as pd
 
label2id = {
    'NONE': 0,
    'EVIDENCE': 1,
    'CLAIM': 2}
 
def load_corpus(path, label_mapping=None):
    with open(path) as fp:
        corpus = json.load(fp)
 
    documents, texts, labels = [], [], []
    for abstract in corpus:
        documents.append(abstract)
        texts.append(corpus[abstract]['sentences'])
        if isinstance(label_mapping, dict):
            labels.append(
                [label_mapping[str(l).upper()]
                    for l in corpus[abstract]['labels']])
        else:
            labels.append([str(l).upper() for l in corpus[abstract]['labels']])
 
    assert len(texts) == len(labels)
    data = pd.DataFrame(
        zip(documents, texts, labels),
        columns=['document', 'sentences', 'labels'])
 
    return data
 
data = load_corpus('dataset_aueb_argument_v1.json') #, label_mapping=label2id)
print(f'Dataset length: {len(data)} abstracts')
data.sample(20)
# Out:
# Dataset length: 916 abstracts
#                                     document  ...                                             labels
# 812            doi: 10.3389/fphys.2018.01306  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 568              doi: 10.1098/rstb.2016.0138  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 276            doi: 10.1021/acs.jctc.6b00979  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 28               doi: 10.1002/anie.201705721  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 835                  doi: 10.3390/jcm9030814  ...  [NEITHER, EVIDENCE, CLAIM, NEITHER, NEITHER, N...
# 363                  doi: 10.1038/nchem.2577  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 348                doi: 10.1029/2019ms001791  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 617             doi: 10.1126/science.aav2211  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 853                       doi: 10.3791/56889  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 758        doi: 10.1371/journal.pone.0226697  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 822                doi: 10.3390/cells8010005  ...               [NEITHER, NEITHER, NEITHER, NEITHER]
# 207  doi: 10.1016/j.jelectrocard.2019.08.008  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 382           doi: 10.1038/s41426-018-0166-2  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 488              doi: 10.1055/s-0036-1590931  ...     [NEITHER, NEITHER, NEITHER, NEITHER, EVIDENCE]
# 26               doi: 10.1002/anie.201700730  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 270            doi: 10.1021/acs.jcim.7b00650  ...  [NEITHER, NEITHER, NEITHER, EVIDENCE, NEITHER,...
# 89            doi: 10.1007/s00382-018-4521-8  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
# 330                doi: 10.1029/2018ms001327  ...  [NEITHER, CLAIM, NEITHER, NEITHER, NEITHER, NE...
# 644                   doi: 10.1159/000447239  ...  [NEITHER, NEITHER, NEITHER, NEITHER, EVIDENCE,...
# 768         doi: 10.1534/genetics.118.300908  ...  [NEITHER, NEITHER, NEITHER, NEITHER, NEITHER, ...
#
# [20 rows x 3 columns]

# %%
# assign sentence column in an object

sentencesargument = data['sentences'].explode().reset_index().rename(
    columns={'index': 'doc_id', 'sentences': 'sentence'})
sentencesargument
# Out:
#       doc_id                                           sentence
# 0          0  Concordance Between Different Amyloid Immunoas...
# 1          0  Importance Visual assessment of amyloid positr...
# 2          0  Several immunoassays have been developed to me...
# 3          0  The agreement between CSF Aβ42 measures from d...
# 4          0  Objective To determine the concordance between...
# ...      ...                                                ...
# 9380     915  Instead, SBPs sample a range of conformations ...
# 9381     915  Certain non-transported ligands leave the stru...
# 9382     915  Intriguingly, in some cases, similar SBP confo...
# 9383     915  In this case, the inability for transport aris...
# 9384     915  Our results reveal the complex interplay betwe...
#
# [9385 rows x 2 columns]

# %%
# assign label column in an object

labelsargument = data['labels'].explode().reset_index().rename(
    columns={'index': 'doc_id', 'lables': 'label'})
labelsargument
# Out:
#       doc_id   labels
# 0          0  NEITHER
# 1          0  NEITHER
# 2          0  NEITHER
# 3          0  NEITHER
# 4          0  NEITHER
# ...      ...      ...
# 9380     915  NEITHER
# 9381     915  NEITHER
# 9382     915  NEITHER
# 9383     915  NEITHER
# 9384     915    CLAIM
#
# [9385 rows x 2 columns]

# %%
# reverse column order in sentenceargument object
s=sentencesargument['sentence']
s1=sentencesargument['doc_id']
sentencesargnew=pd.concat([s,s1],axis=1)
sentencesargnew
# Out:
#                                                sentence  doc_id
# 0     Concordance Between Different Amyloid Immunoas...       0
# 1     Importance Visual assessment of amyloid positr...       0
# 2     Several immunoassays have been developed to me...       0
# 3     The agreement between CSF Aβ42 measures from d...       0
# 4     Objective To determine the concordance between...       0
# ...                                                 ...     ...
# 9380  Instead, SBPs sample a range of conformations ...     915
# 9381  Certain non-transported ligands leave the stru...     915
# 9382  Intriguingly, in some cases, similar SBP confo...     915
# 9383  In this case, the inability for transport aris...     915
# 9384  Our results reveal the complex interplay betwe...     915
#
# [9385 rows x 2 columns]

# %%
# merge sentence argument and label argument in the same df named dataargument
dataargument = pd.merge(sentencesargument, 
               labelsargument, 
               left_index=True, right_index=True)
dataargument
print(dataargument.shape)
dataargument.head(5)
# Out:
# (9385, 4)
#    doc_id_x  ...   labels
# 0         0  ...  NEITHER
# 1         0  ...  NEITHER
# 2         0  ...  NEITHER
# 3         0  ...  NEITHER
# 4         0  ...  NEITHER
#
# [5 rows x 4 columns]

# %%
# group by argument label
dataargument.groupby(by=["labels"], dropna=False).count()
# Out:
#           doc_id_x  sentence  doc_id_y
# labels
# CLAIM          954       954       954
# EVIDENCE      1578      1578      1578
# NEITHER       6853      6853      6853

# %%
# from dataargument dataframe keep the rows that habel argument label "evidence" and name the df evidence
evidence = dataargument.loc[(dataargument['labels'] == 'EVIDENCE')]
evidence.head(4)
evidence.shape
evidence
# Out:
#       doc_id_x  ...    labels
# 8            0  ...  EVIDENCE
# 9            0  ...  EVIDENCE
# 10           0  ...  EVIDENCE
# 11           0  ...  EVIDENCE
# 12           0  ...  EVIDENCE
# ...        ...  ...       ...
# 9302       907  ...  EVIDENCE
# 9304       907  ...  EVIDENCE
# 9340       910  ...  EVIDENCE
# 9364       913  ...  EVIDENCE
# 9373       914  ...  EVIDENCE
#
# [1578 rows x 4 columns]

# %%
# assign column sentence from evidence and convert it to dataframe named "e"
evidence_s=evidence['sentence']
e=pd.DataFrame(data=evidence_s)
e
# Out:
#                                                sentence
# 8     Main Outcomes and Measures The concordance of ...
# 9     Results Of 262 participants (mean [SD] age, 70...
# 10    The mass spectrometry–derived Aβ42 values show...
# 11    The signal in the classic Aβ42-INNOTEST assay ...
# 12    However, the classic Aβ42-INNOTEST assay showe...
# ...                                                 ...
# 9302  Our results demonstrate that the generalized P...
# 9304  Spatially, our estimations suggest a higher pr...
# 9340  These show that higher values of P* generally ...
# 9364  Our study generalizes a previous one by Fukush...
# 9373  We propose that GLP-1/Notch promotes reprogram...
#
# [1578 rows x 1 columns]

# %%
# split dataframe "e" 
e["sentence"]= e["sentence"].str.split(" ")
e
# Out:
#                                                sentence
# 8     [Main, Outcomes, and, Measures, The, concordan...
# 9     [Results, Of, 262, participants, (mean, [SD], ...
# 10    [The, mass, spectrometry–derived, Aβ42, values...
# 11    [The, signal, in, the, classic, Aβ42-INNOTEST,...
# 12    [However,, the, classic, Aβ42-INNOTEST, assay,...
# ...                                                 ...
# 9302  [Our, results, demonstrate, that, the, general...
# 9304  [Spatially,, our, estimations, suggest, a, hig...
# 9340  [These, show, that, higher, values, of, P*, ge...
# 9364  [Our, study, generalizes, a, previous, one, by...
# 9373  [We, propose, that, GLP-1/Notch, promotes, rep...
#
# [1578 rows x 1 columns]

# %%
# from dataframe "e" create index and put each word in a different raw with explode, assign the result in dataframe evidence words
# in order to detect keywords that reveal evidence label
evidence_words = e['sentence'].explode().reset_index().rename(
    columns={'index': 'doc_id', 'sentence': 'evidence_words'})
evidence_words
# Out:
#        doc_id evidence_words
# 0           8           Main
# 1           8       Outcomes
# 2           8            and
# 3           8       Measures
# 4           8            The
# ...       ...            ...
# 39270    9373        crucial
# 39271    9373    GLP-1/Notch
# 39272    9373         target
# 39273    9373   facilitating
# 39274    9373  reprograming.
#
# [39275 rows x 2 columns]

# %%
#Use lower case letters for all words
evidence_words['evidence_words']=evidence_words['evidence_words'].str.lower()
evidence_words
# Out:
#        doc_id evidence_words  count
# 0           8           main      2
# 1           8       outcomes      2
# 2           8            and   1442
# 3           8       measures      2
# 4           8            the    242
# ...       ...            ...    ...
# 39270    9373        crucial      5
# 39271    9373    glp-1/notch      2
# 39272    9373         target      6
# 39273    9373   facilitating      2
# 39274    9373  reprograming.      1
#
# [39275 rows x 3 columns]

# %%
#Use observed symbols
b = "!,().[]:"
for char in b:
    evidence_words['evidence_words']=evidence_words['evidence_words'].str.replace(char, "")

# %%
# count how many times each word appears in data frame evidence_words
evidence_words['count'] = evidence_words.groupby('evidence_words')['evidence_words'].transform('count')
evidence_words
# Out:
#        doc_id evidence_words  count
# 0           8           main      7
# 1           8       outcomes      3
# 2           8            and   1445
# 3           8       measures      9
# 4           8            the   2052
# ...       ...            ...    ...
# 39270    9373        crucial      5
# 39271    9373    glp-1/notch      2
# 39272    9373         target      8
# 39273    9373   facilitating      2
# 39274    9373   reprograming      2
#
# [39275 rows x 3 columns]

# %%
# keep unique values and name the new data frame evunique
evunique=evidence_words.drop_duplicates(subset='evidence_words')
evunique
# Out:
#        doc_id evidence_words  count
# 0           8           main      7
# 1           8       outcomes      3
# 2           8            and   1445
# 3           8       measures      9
# 4           8            the   2052
# ...       ...            ...    ...
# 39253    9373       silenced      1
# 39256    9373       polycomb      1
# 39260    9373           prc2      1
# 39266    9373    demethylase      1
# 39267    9373          utx-1      1
#
# [8509 rows x 3 columns]

# %%
#sort evunique in descending order to the column count and name the new data frame ev1
ev1=evunique.sort_values(by='count', ascending=False, na_position='first')
ev1.head(50)
# Out:
#       doc_id evidence_words  count
# 4          8            the   2052
# 2          8            and   1445
# 6          8             of   1422
# 69        11             in   1041
# 123       13             to    704
# 140       14              a    578
# 15         8           with    529
# 306       36           that    366
# 614       63            for    358
# 254       28             is    286
# 304       36             we    275
# 77        11             by    271
# 74        11            was    222
# 31         9           were    216
# 349       37             as    213
# 179       26           from    197
# 217       28             at    181
# 437       46             on    173
# 276       29            are    167
# 20         9        results    156
# 277       29             an    147
# 738       77        between    140
# 364       44           this    112
# 152       14            not    109
# 1017     141           than    106
# 129       13             or     95
# 45        10         higher     91
# 175       26       patients     90
# 310       36             be     90
# 216       28      increased     88
# 798       89           more     83
# 492       48     associated     83
# 431       46          these     83
# 527       55          model     80
# 1007     141            but     80
# 863       92           also     79
# 509       55           show     79
# 60        10       compared     78
# 438       46          which     77
# 610       63              p     73
# 345       37           over     72
# 417       45           both     70
# 118       13           when     69
# 673       66            can     69
# 415       45         during     67
# 1386     305          using     67
# 44        10         showed     67
# 9          8         levels     66
# 571       61            our     64
# 2269     557            all     62

# %%
#for the evidence word, chek if there are similar expressions
import re
evid = ev1[ev1['evidence_words'].str.contains(r'^eviden', flags=re.IGNORECASE)]
evid
# Out:
#        doc_id evidence_words  count
# 1337      271       evidence     29
# 350        37      evidenced      2
# 36850    8164        evident      1

# %%
##one hundrent most commonly used words
listofevidence=ev1['evidence_words'][0:100].tolist()
listofevidence
# Out:
# ['the',
#  'and',
#  'of',
#  'in',
#  'to',
#  'a',
#  'with',
#  'that',
#  'for',
#  'is',
#  'we',
#  'by',
#  'was',
#  'were',
#  'as',
#  'from',
#  'at',
#  'on',
#  'are',
#  'results',
#  'an',
#  'between',
#  'this',
#  'not',
#  'than',
#  'or',
#  'higher',
#  'patients',
#  'be',
#  'increased',
#  'more',
#  'associated',
#  'these',
#  'model',
#  'but',
#  'also',
#  'show',
#  'compared',
#  'which',
#  'p',
#  'over',
#  'both',
#  'when',
#  'can',
#  'during',
#  'using',
#  'showed',
#  'levels',
#  'our',
#  'all',
#  'analysis',
#  '=',
#  'high',
#  'climate',
#  'different',
#  'found',
#  '95%',
#  'significantly',
#  'ci',
#  'observed',
#  'significant',
#  'models',
#  'mean',
#  'lower',
#  'reduced',
#  'changes',
#  '1',
#  'decreased',
#  'after',
#  'had',
#  'csf',
#  'have',
#  'other',
#  'only',
#  'while',
#  'under',
#  'most',
#  'increase',
#  'baseline',
#  'data',
#  'within',
#  'effect',
#  'zikv',
#  'temperature',
#  'time',
#  'their',
#  'global',
#  'disease',
#  'change',
#  'well',
#  'respectively',
#  '2',
#  'expression',
#  'cells',
#  'controls',
#  'find',
#  '<',
#  'such',
#  'emissions',
#  'study']

# %%
#create our stop word list
cleanevidence=['the',
 'and',
 'of',
 'in',
 'to',
 'a',
 'with',
 'that',
 'for',
 'is',
 'we',
 'by',
 'was',
 'were',
 'as',
 'from',
 'at',
 'on',
 'are',
 'an',
 'between',
 'this',
 'not',
 'than',
 'or',
 'be',
 'more',
 'these',
 'but',
 'also',
 'which',
 'over',
 'both',
 'when',
 'can',
 'our',
 'all',
 'after',
 'had',
 'csf',
 'have',
 'other',
 'only',
 'while',
 'under',
 'most',
 'their']

# %%
#keep words appeared more than once
evtry=ev1[ev1['count']>2]
evtry
# Out:
#        doc_id evidence_words  count
# 4           8            the   2052
# 2           8            and   1445
# 6           8             of   1422
# 69         11             in   1041
# 123        13             to    704
# ...       ...            ...    ...
# 422        45      forecasts      3
# 7980     1838      prevalent      3
# 30223    6418            lps      3
# 421        45        weather      3
# 414        45     hemisphere      3
#
# [2327 rows x 3 columns]

# %%
#clean the words list
evtry = evtry[~evtry['evidence_words'].isin(cleanevidence)]
evtry
# Out:
#        doc_id evidence_words  count
# 20          9        results    156
# 45         10         higher     91
# 175        26       patients     90
# 216        28      increased     88
# 492        48     associated     83
# ...       ...            ...    ...
# 422        45      forecasts      3
# 7980     1838      prevalent      3
# 30223    6418            lps      3
# 421        45        weather      3
# 414        45     hemisphere      3
#
# [2280 rows x 3 columns]

# %%
#keep words with count more than 30
evtest1=evtry[evtry['count']>30]
evtest1
# Out:
#       doc_id evidence_words  count
# 20         9        results    156
# 45        10         higher     91
# 175       26       patients     90
# 216       28      increased     88
# 492       48     associated     83
# ...      ...            ...    ...
# 904      105    sensitivity     33
# 165       25         plasma     32
# 1065     162         energy     31
# 1587     418             vs     31
# 2245     536             no     31
#
# [70 rows x 3 columns]

# %%
ev=evtest1['evidence_words'].tolist()
ev
# Out:
# ['results',
#  'higher',
#  'patients',
#  'increased',
#  'associated',
#  'model',
#  'show',
#  'compared',
#  'p',
#  'during',
#  'using',
#  'showed',
#  'levels',
#  'analysis',
#  '=',
#  'high',
#  'climate',
#  'different',
#  'found',
#  '95%',
#  'significantly',
#  'ci',
#  'observed',
#  'significant',
#  'models',
#  'mean',
#  'lower',
#  'reduced',
#  'changes',
#  '1',
#  'decreased',
#  'increase',
#  'baseline',
#  'data',
#  'within',
#  'effect',
#  'zikv',
#  'temperature',
#  'time',
#  'global',
#  'disease',
#  'change',
#  'well',
#  'respectively',
#  '2',
#  'expression',
#  'cells',
#  'controls',
#  'find',
#  '<',
#  'such',
#  'emissions',
#  'study',
#  'due',
#  'differences',
#  'it',
#  'two',
#  'identified',
#  'total',
#  'years',
#  'however',
#  'precipitation',
#  'infection',
#  'effects',
#  'low',
#  'sensitivity',
#  'plasma',
#  'energy',
#  'vs',
#  'no']

# %%
#select the words for our list
ev=['results',
 'higher',
 'patients',
 'increased',
 'associated',
 'model',
 'show',
 'compared',
 'p',
 'during',
 'using',
 'showed',
 'levels',
 'analysis',
 '=',
 'high',
 'climate',
 'different',
 'found',
 '95%',
 'significantly',
 'ci',
 'observed',
 'significant',
 'models',
 'mean',
 'lower',
 'reduced',
 'changes',
 '1',
 'decreased',
 'increase',
 'baseline',
 'data',
 'within',
 'effect',
 'zikv',
 'temperature',
 'time',
 'global',
 'disease',
 'change',
 'well',
 'respectively',
 '2',
 'expression',
 'cells',
 'controls',
 'find',
 '<',
 'such',
 'emissions',
 'study',
 'due',
 'differences',
 'it',
 'two',
 'identified',
 'total',
 'years',
 'however',
 'precipitation',
 'infection',
 'effects',
 'low',
 'sensitivity',
 'plasma',
 'energy',
 'vs',
 'no']

# %%
# we assign column sentence in a new object called test1
test1 = dataargument['sentence']

# %%
#we transfrom test1 in df with library pandas and assigned in a new variable named t and after in new variable named test2. 
t=pd.DataFrame(test1)
test2=t
# we create a new column in test2 named label and write the value none 
test2['LABEL']='NONE'
test2
# Out:
#                                                sentence LABEL
# 0     Concordance Between Different Amyloid Immunoas...  NONE
# 1     Importance Visual assessment of amyloid positr...  NONE
# 2     Several immunoassays have been developed to me...  NONE
# 3     The agreement between CSF Aβ42 measures from d...  NONE
# 4     Objective To determine the concordance between...  NONE
# ...                                                 ...   ...
# 9380  Instead, SBPs sample a range of conformations ...  NONE
# 9381  Certain non-transported ligands leave the stru...  NONE
# 9382  Intriguingly, in some cases, similar SBP confo...  NONE
# 9383  In this case, the inability for transport aris...  NONE
# 9384  Our results reveal the complex interplay betwe...  NONE
#
# [9385 rows x 2 columns]

# %%
wordsevidence_df=test2
wordsevidence_df
# Out:
#                                                sentence LABEL
# 0     Concordance Between Different Amyloid Immunoas...  NONE
# 1     Importance Visual assessment of amyloid positr...  NONE
# 2     Several immunoassays have been developed to me...  NONE
# 3     The agreement between CSF Aβ42 measures from d...  NONE
# 4     Objective To determine the concordance between...  NONE
# ...                                                 ...   ...
# 9380  Instead, SBPs sample a range of conformations ...  NONE
# 9381  Certain non-transported ligands leave the stru...  NONE
# 9382  Intriguingly, in some cases, similar SBP confo...  NONE
# 9383  In this case, the inability for transport aris...  NONE
# 9384  Our results reveal the complex interplay betwe...  NONE
#
# [9385 rows x 2 columns]

# %%
for ind in wordsevidence_df.index:
  splits = str.split(test1[ind])
  for split in splits:
      if split in ev:    
        wordsevidence_df['LABEL'][ind] = 'evidence'

# %%
wordsevidence_df.head(40)
# Out:
#                                              sentence     LABEL
# 0   Concordance Between Different Amyloid Immunoas...      NONE
# 1   Importance Visual assessment of amyloid positr...      NONE
# 2   Several immunoassays have been developed to me...      NONE
# 3   The agreement between CSF Aβ42 measures from d...  evidence
# 4   Objective To determine the concordance between...  evidence
# 5   Design, Setting, and Participants The study in...  evidence
# 6   Levels of CSF Aβ42 were analyzed using the cla...  evidence
# 7   Concentrations of CSF Aβ were assessed using a...  evidence
# 8   Main Outcomes and Measures The concordance of ...  evidence
# 9   Results Of 262 participants (mean [SD] age, 70...      NONE
# 10  The mass spectrometry–derived Aβ42 values show...  evidence
# 11  The signal in the classic Aβ42-INNOTEST assay ...      NONE
# 12  However, the classic Aβ42-INNOTEST assay showe...  evidence
# 13  The accuracies of the newer assays improved si...  evidence
# 14  A combination of the Aβ42:Aβ40 ratio and T-tau...  evidence
# 15  Conclusions and Relevance Concentrations of CS...  evidence
# 16  These findings suggest the benefit of implemen...      NONE
# 17  Association of Changes in Plasma Neurofilament...      NONE
# 18  Importance Anesthesia and surgery are believed...      NONE
# 19  Evidence that neurological sequelae may follow...      NONE
# 20  Objective To measure 2 biomarkers of neurologi...  evidence
# 21  Design, Setting, and Participants These 2 rela...  evidence
# 22  Blood samples were taken immediately before su...      NONE
# 23  Sampling took place from January 2014 to Augus...      NONE
# 24  Data analysis took place from October 2016 to ...  evidence
# 25  Main Outcomes and Measures Plasma neurofilamen...      NONE
# 26  Results A total of 30 patients were enrolled (...  evidence
# 27  The mean (SD) age was 69.1 (7.0) years, and 18...  evidence
# 28  Mean neurofilament light increased at each mea...  evidence
# 29  Tau proteins are an integral component of axon...  evidence
# 30  The increases in both neurofilament light and ...  evidence
# 31  Further investigations will be required to stu...  evidence
# 32  These preliminary findings demand that we ques...  evidence
# 33  Dynamically triggered slip leading to sustaine...      NONE
# 34  We investigate dynamic wave-triggered slip und...      NONE
# 35  The experiment is composed of a three-block sy...  evidence
# 36  When the system is sheared under steady state ...  evidence
# 37  Following triggering, the gouge material remai...      NONE
# 38  This work suggests that faults must be critica...      NONE
# 39  Impacts of parameterized orographic drag on th...      NONE

# %%
wordsevidence_df['LABEL'].value_counts()
# Out:
# evidence    5521
# NONE        3864
# Name: LABEL, dtype: int64

# %%
cross2['LABEL'].value_counts()
# Out:
# evidence    1191
# NONE         387
# Name: LABEL, dtype: int64

# %%
cross2 = pd.merge(test2, 
               evidence, 
               left_index=True, right_index=True)


print(cross2.shape)
cross2.head(50)
# Out:
# (1578, 6)
#                                             sentence_x  ...    labels
# 8    Main Outcomes and Measures The concordance of ...  ...  EVIDENCE
# 9    Results Of 262 participants (mean [SD] age, 70...  ...  EVIDENCE
# 10   The mass spectrometry–derived Aβ42 values show...  ...  EVIDENCE
# 11   The signal in the classic Aβ42-INNOTEST assay ...  ...  EVIDENCE
# 12   However, the classic Aβ42-INNOTEST assay showe...  ...  EVIDENCE
# 13   The accuracies of the newer assays improved si...  ...  EVIDENCE
# 14   A combination of the Aβ42:Aβ40 ratio and T-tau...  ...  EVIDENCE
# 25   Main Outcomes and Measures Plasma neurofilamen...  ...  EVIDENCE
# 26   Results A total of 30 patients were enrolled (...  ...  EVIDENCE
# 27   The mean (SD) age was 69.1 (7.0) years, and 18...  ...  EVIDENCE
# 28   Mean neurofilament light increased at each mea...  ...  EVIDENCE
# 29   Tau proteins are an integral component of axon...  ...  EVIDENCE
# 36   When the system is sheared under steady state ...  ...  EVIDENCE
# 37   Following triggering, the gouge material remai...  ...  EVIDENCE
# 44   This increase was simulated in two ways, namel...  ...  EVIDENCE
# 45   Increasing the parameterized orographic drag l...  ...  EVIDENCE
# 46   However, the magnitude of these changes in cir...  ...  EVIDENCE
# 47   In 10 day forecasts, stronger changes are foun...  ...  EVIDENCE
# 48   At these time scales, the BLOCK scheme affects...  ...  EVIDENCE
# 55   Here we show that the effects of switching off...  ...  EVIDENCE
# 61   Our experiments show an evolution from stable ...  ...  EVIDENCE
# 62   To evaluate the microphysical processes of fau...  ...  EVIDENCE
# 63   We find systematic changes in P wave velocity ...  ...  EVIDENCE
# 64   During the coseismic stress drop, seismic velo...  ...  EVIDENCE
# 65   In the preparatory phase preceding failure, we...  ...  EVIDENCE
# 66   Our results suggest that the mechanics of slow...  ...  EVIDENCE
# 67   In agreement with seismic surveys on tectonic ...  ...  EVIDENCE
# 77   The intercomparison reproduces the typical bia...  ...  EVIDENCE
# 78   In some models, high emissivities of ice cloud...  ...  EVIDENCE
# 79   Models substantially disagree on the amount of...  ...  EVIDENCE
# 89   Results At disease presentation, ACPA‐negative...  ...  EVIDENCE
# 90   During followup, ACPA‐negative patients remain...  ...  EVIDENCE
# 91   Thirty‐eight percent of ACPA‐negative and 48% ...  ...  EVIDENCE
# 92   Also, restrictions at work among employed pati...  ...  EVIDENCE
# 105  These fibers, exposing hydrophilic ethylene gl...  ...  EVIDENCE
# 116  Surprisingly, a colossal increase (3000-fold) ...  ...  EVIDENCE
# 118  The effect is fast (<400 ms) and fully reversi...  ...  EVIDENCE
# 139  For even integer values of the parameter, the ...  ...  EVIDENCE
# 140  For non‐integer β, relative errors in observab...  ...  EVIDENCE
# 141  For odd integer values of β, floating‐point re...  ...  EVIDENCE
# 162  Moreover, electrochemical and theoretical stud...  ...  EVIDENCE
# 175  9 times more crystallization space than a rand...  ...  EVIDENCE
# 176  6 times more than humans and increases the cry...  ...  EVIDENCE
# 186  We show that {CAT}⊂{Mo24Fe12} with different C...  ...  EVIDENCE
# 192  Solution circular dichroism studies show that ...  ...  EVIDENCE
# 204  Not only do we observe about 120 new species, ...  ...  EVIDENCE
# 206              43 new species in the D world and ca.  ...  EVIDENCE
# 207                     39 new species in the H world.  ...  EVIDENCE
# 220  Moreover, the observation of the parent uncapp...  ...  EVIDENCE
# 226  9 times more crystallization space than a rand...  ...  EVIDENCE
#
# [50 rows x 6 columns]

# %%
##SYMBOLS

# %%
sym = ["%","*","<",">","+","β","=","±","‰","Ξ²","Ξ","²"]

# %%
# preparation  symbols dataframe
test2['LABEL']='NONE'
symbols_df=test2
symbols_df
# Out:
#                                                sentence LABEL
# 0     Concordance Between Different Amyloid Immunoas...  NONE
# 1     Importance Visual assessment of amyloid positr...  NONE
# 2     Several immunoassays have been developed to me...  NONE
# 3     The agreement between CSF Aβ42 measures from d...  NONE
# 4     Objective To determine the concordance between...  NONE
# ...                                                 ...   ...
# 9380  Instead, SBPs sample a range of conformations ...  NONE
# 9381  Certain non-transported ligands leave the stru...  NONE
# 9382  Intriguingly, in some cases, similar SBP confo...  NONE
# 9383  In this case, the inability for transport aris...  NONE
# 9384  Our results reveal the complex interplay betwe...  NONE
#
# [9385 rows x 2 columns]

# %%
# for loop that checks the symbol through text line. Assigns evidence label in the dataframe symbols_df when it finds symbols contained in the list sym.
for ind in symbols_df.index:
  #splits = str.split(test1[ind])
  for split in symbols_df['sentence'][ind]:
      if split in sym:    
        symbols_df['LABEL'][ind] = 'evidence'

# %%
symbols_df
# Out:
#                                                sentence     LABEL
# 0     Concordance Between Different Amyloid Immunoas...      NONE
# 1     Importance Visual assessment of amyloid positr...      NONE
# 2     Several immunoassays have been developed to me...  evidence
# 3     The agreement between CSF Aβ42 measures from d...  evidence
# 4     Objective To determine the concordance between...  evidence
# ...                                                 ...       ...
# 9380  Instead, SBPs sample a range of conformations ...      NONE
# 9381  Certain non-transported ligands leave the stru...      NONE
# 9382  Intriguingly, in some cases, similar SBP confo...      NONE
# 9383  In this case, the inability for transport aris...      NONE
# 9384  Our results reveal the complex interplay betwe...      NONE
#
# [9385 rows x 2 columns]

# %%
# count how many evidence label we found with symbol for loop
symbols_df['LABEL'].value_counts()
# Out:
# NONE        8464
# evidence     921
# Name: LABEL, dtype: int64

# %%
cross2 = pd.merge(symbols_df, 
               evidence, 
               left_index=True, right_index=True)


print(cross2.shape)
cross2.head(50)
# Out:
# (1578, 6)
#                                             sentence_x  ...    labels
# 8    Main Outcomes and Measures The concordance of ...  ...  EVIDENCE
# 9    Results Of 262 participants (mean [SD] age, 70...  ...  EVIDENCE
# 10   The mass spectrometry–derived Aβ42 values show...  ...  EVIDENCE
# 11   The signal in the classic Aβ42-INNOTEST assay ...  ...  EVIDENCE
# 12   However, the classic Aβ42-INNOTEST assay showe...  ...  EVIDENCE
# 13   The accuracies of the newer assays improved si...  ...  EVIDENCE
# 14   A combination of the Aβ42:Aβ40 ratio and T-tau...  ...  EVIDENCE
# 25   Main Outcomes and Measures Plasma neurofilamen...  ...  EVIDENCE
# 26   Results A total of 30 patients were enrolled (...  ...  EVIDENCE
# 27   The mean (SD) age was 69.1 (7.0) years, and 18...  ...  EVIDENCE
# 28   Mean neurofilament light increased at each mea...  ...  EVIDENCE
# 29   Tau proteins are an integral component of axon...  ...  EVIDENCE
# 36   When the system is sheared under steady state ...  ...  EVIDENCE
# 37   Following triggering, the gouge material remai...  ...  EVIDENCE
# 44   This increase was simulated in two ways, namel...  ...  EVIDENCE
# 45   Increasing the parameterized orographic drag l...  ...  EVIDENCE
# 46   However, the magnitude of these changes in cir...  ...  EVIDENCE
# 47   In 10 day forecasts, stronger changes are foun...  ...  EVIDENCE
# 48   At these time scales, the BLOCK scheme affects...  ...  EVIDENCE
# 55   Here we show that the effects of switching off...  ...  EVIDENCE
# 61   Our experiments show an evolution from stable ...  ...  EVIDENCE
# 62   To evaluate the microphysical processes of fau...  ...  EVIDENCE
# 63   We find systematic changes in P wave velocity ...  ...  EVIDENCE
# 64   During the coseismic stress drop, seismic velo...  ...  EVIDENCE
# 65   In the preparatory phase preceding failure, we...  ...  EVIDENCE
# 66   Our results suggest that the mechanics of slow...  ...  EVIDENCE
# 67   In agreement with seismic surveys on tectonic ...  ...  EVIDENCE
# 77   The intercomparison reproduces the typical bia...  ...  EVIDENCE
# 78   In some models, high emissivities of ice cloud...  ...  EVIDENCE
# 79   Models substantially disagree on the amount of...  ...  EVIDENCE
# 89   Results At disease presentation, ACPA‐negative...  ...  EVIDENCE
# 90   During followup, ACPA‐negative patients remain...  ...  EVIDENCE
# 91   Thirty‐eight percent of ACPA‐negative and 48% ...  ...  EVIDENCE
# 92   Also, restrictions at work among employed pati...  ...  EVIDENCE
# 105  These fibers, exposing hydrophilic ethylene gl...  ...  EVIDENCE
# 116  Surprisingly, a colossal increase (3000-fold) ...  ...  EVIDENCE
# 118  The effect is fast (<400 ms) and fully reversi...  ...  EVIDENCE
# 139  For even integer values of the parameter, the ...  ...  EVIDENCE
# 140  For non‐integer β, relative errors in observab...  ...  EVIDENCE
# 141  For odd integer values of β, floating‐point re...  ...  EVIDENCE
# 162  Moreover, electrochemical and theoretical stud...  ...  EVIDENCE
# 175  9 times more crystallization space than a rand...  ...  EVIDENCE
# 176  6 times more than humans and increases the cry...  ...  EVIDENCE
# 186  We show that {CAT}⊂{Mo24Fe12} with different C...  ...  EVIDENCE
# 192  Solution circular dichroism studies show that ...  ...  EVIDENCE
# 204  Not only do we observe about 120 new species, ...  ...  EVIDENCE
# 206              43 new species in the D world and ca.  ...  EVIDENCE
# 207                     39 new species in the H world.  ...  EVIDENCE
# 220  Moreover, the observation of the parent uncapp...  ...  EVIDENCE
# 226  9 times more crystallization space than a rand...  ...  EVIDENCE
#
# [50 rows x 6 columns]

# %%
cross2=pd.DataFrame(cross2)
cross2
# Out:
#                                              sentence_x  ...    labels
# 8     Main Outcomes and Measures The concordance of ...  ...  EVIDENCE
# 9     Results Of 262 participants (mean [SD] age, 70...  ...  EVIDENCE
# 10    The mass spectrometry–derived Aβ42 values show...  ...  EVIDENCE
# 11    The signal in the classic Aβ42-INNOTEST assay ...  ...  EVIDENCE
# 12    However, the classic Aβ42-INNOTEST assay showe...  ...  EVIDENCE
# ...                                                 ...  ...       ...
# 9302  Our results demonstrate that the generalized P...  ...  EVIDENCE
# 9304  Spatially, our estimations suggest a higher pr...  ...  EVIDENCE
# 9340  These show that higher values of P* generally ...  ...  EVIDENCE
# 9364  Our study generalizes a previous one by Fukush...  ...  EVIDENCE
# 9373  We propose that GLP-1/Notch promotes reprogram...  ...  EVIDENCE
#
# [1578 rows x 6 columns]

# %%
# how many evidence label were assigned 
#with our for loop using symbols list.
cross2['LABEL'].value_counts()
# Out:
# NONE        1173
# evidence     405
# Name: LABEL, dtype: int64
